# %%
import pandas as pd
import numpy as np
import re
import nltk

# %%
df=pd.read_csv("IMDB_testset.csv")

# %%
df['clean_plot']=df['Plot'].str.lower()
df['clean_plot']=df['clean_plot'].apply(lambda x: re.sub('[^a-zA-Z]',' ',x))
df['clean_plot']=df['clean_plot'].apply(lambda x: re.sub('\s+',' ',x))

# %%
df['clean_plot']=df["clean_plot"].apply(lambda x: nltk.word_tokenize(x))

# %%
stop_word=nltk.corpus.stopwords.words('english')
plot=[]
for sentence in df['clean_plot']:
    temp=[]
    for word in sentence:
        if word not in stop_word and len(word)>=3:
            temp.append(word)
    plot.append(temp)

# %%
df['clean_plot']=plot

# %%
plot
# Out:
# [['paraplegic',
#   'marine',
#   'dispatched',
#   'moon',
#   'pandora',
#   'unique',
#   'mission',
#   'becomes',
#   'torn',
#   'following',
#   'orders',
#   'protecting',
#   'world',
#   'feels',
#   'home'],
#  ['captain',
#   'barbossa',
#   'turner',
#   'elizabeth',
#   'swann',
#   'must',
#   'sail',
#   'edge',
#   'map',
#   'navigate',
#   'treachery',
#   'betrayal',
#   'find',
#   'jack',
#   'sparrow',
#   'make',
#   'final',
#   'alliances',
#   'one',
#   'last',
#   'decisive',
#   'battle'],
#  ['cryptic',
#   'message',
#   'bond',
#   'past',
#   'sends',
#   'trail',
#   'uncover',
#   'sinister',
#   'organization',
#   'battles',
#   'political',
#   'forces',
#   'keep',
#   'secret',
#   'service',
#   'alive',
#   'bond',
#   'peels',
#   'back',
#   'layers',
#   'deceit',
#   'reveal',
#   'terrible',
#   'truth',
#   'behind',
#   'spectre'],
#  ['eight',
#   'years',
#   'joker',
#   'reign',
#   'anarchy',
#   'dark',
#   'knight',
#   'help',
#   'enigmatic',
#   'selina',
#   'forced',
#   'imposed',
#   'exile',
#   'save',
#   'gotham',
#   'city',
#   'edge',
#   'total',
#   'annihilation',
#   'brutal',
#   'guerrilla',
#   'terrorist',
#   'bane'],
#  ['native',
#   'american',
#   'warrior',
#   'tonto',
#   'recounts',
#   'untold',
#   'tales',
#   'transformed',
#   'john',
#   'reid',
#   'man',
#   'law',
#   'legend',
#   'justice'],
#  ['transported',
#   'barsoom',
#   'civil',
#   'war',
#   'vet',
#   'discovers',
#   'barren',
#   'planet',
#   'seemingly',
#   'inhabited',
#   'foot',
#   'tall',
#   'barbarians',
#   'finding',
#   'prisoner',
#   'creatures',
#   'escapes',
#   'encounter',
#   'woola',
#   'princess',
#   'desperate',
#   'need',
#   'savior'],
#  ['magically',
#   'long',
#   'haired',
#   'rapunzel',
#   'spent',
#   'entire',
#   'life',
#   'tower',
#   'runaway',
#   'thief',
#   'stumbled',
#   'upon',
#   'discover',
#   'world',
#   'first',
#   'time',
#   'really'],
#  ['strange',
#   'black',
#   'entity',
#   'another',
#   'world',
#   'bonds',
#   'peter',
#   'parker',
#   'causes',
#   'inner',
#   'turmoil',
#   'contends',
#   'new',
#   'villains',
#   'temptations',
#   'revenge'],
#  ['tony',
#   'stark',
#   'bruce',
#   'banner',
#   'try',
#   'jump',
#   'start',
#   'dormant',
#   'peacekeeping',
#   'program',
#   'called',
#   'ultron',
#   'things',
#   'horribly',
#   'wrong',
#   'earth',
#   'mightiest',
#   'heroes',
#   'stop',
#   'villainous',
#   'ultron',
#   'enacting',
#   'terrible',
#   'plan'],
#  ['political',
#   'interference',
#   'avengers',
#   'activities',
#   'causes',
#   'rift',
#   'former',
#   'allies',
#   'captain',
#   'america',
#   'iron',
#   'man'],
#  ['fearing',
#   'actions',
#   'superman',
#   'left',
#   'unchecked',
#   'batman',
#   'takes',
#   'man',
#   'steel',
#   'world',
#   'wrestles',
#   'kind',
#   'hero',
#   'really',
#   'needs'],
#  ['reluctant',
#   'hobbit',
#   'bilbo',
#   'baggins',
#   'sets',
#   'lonely',
#   'mountain',
#   'spirited',
#   'group',
#   'dwarves',
#   'reclaim',
#   'mountain',
#   'home',
#   'gold',
#   'within',
#   'dragon',
#   'smaug'],
#  ['harry',
#   'potter',
#   'begins',
#   'sixth',
#   'year',
#   'hogwarts',
#   'discovers',
#   'old',
#   'book',
#   'marked',
#   'property',
#   'half',
#   'blood',
#   'prince',
#   'begins',
#   'learn',
#   'lord',
#   'voldemort',
#   'dark',
#   'past'],
#  ['dwarves',
#   'along',
#   'bilbo',
#   'baggins',
#   'gandalf',
#   'grey',
#   'continue',
#   'quest',
#   'reclaim',
#   'erebor',
#   'homeland',
#   'smaug',
#   'bilbo',
#   'baggins',
#   'possession',
#   'mysterious',
#   'magical',
#   'ring'],
#  ['bilbo',
#   'company',
#   'forced',
#   'engage',
#   'war',
#   'array',
#   'combatants',
#   'keep',
#   'lonely',
#   'mountain',
#   'falling',
#   'hands',
#   'rising',
#   'darkness'],
#  ['jack',
#   'sparrow',
#   'barbossa',
#   'embark',
#   'quest',
#   'find',
#   'elusive',
#   'fountain',
#   'youth',
#   'discover',
#   'blackbeard',
#   'daughter'],
#  ['superman',
#   'reappears',
#   'long',
#   'absence',
#   'challenged',
#   'old',
#   'foe',
#   'uses',
#   'kryptonian',
#   'technology',
#   'world',
#   'domination'],
#  ['james',
#   'bond',
#   'descends',
#   'mystery',
#   'tries',
#   'stop',
#   'mysterious',
#   'organization',
#   'eliminating',
#   'country',
#   'valuable',
#   'resource',
#   'still',
#   'tries',
#   'seek',
#   'revenge',
#   'death',
#   'love'],
#  ['earth',
#   'mightiest',
#   'heroes',
#   'must',
#   'come',
#   'together',
#   'learn',
#   'fight',
#   'team',
#   'stop',
#   'mischievous',
#   'loki',
#   'alien',
#   'army',
#   'enslaving',
#   'humanity'],
#  ['jack',
#   'sparrow',
#   'races',
#   'recover',
#   'heart',
#   'davy',
#   'jones',
#   'avoid',
#   'enslaving',
#   'soul',
#   'jones',
#   'service',
#   'friends',
#   'foes',
#   'seek',
#   'heart',
#   'agenda',
#   'well'],
#  ['clark',
#   'kent',
#   'one',
#   'last',
#   'extinguished',
#   'race',
#   'disguised',
#   'unremarkable',
#   'human',
#   'forced',
#   'reveal',
#   'identity',
#   'earth',
#   'invaded',
#   'army',
#   'survivors',
#   'threaten',
#   'bring',
#   'planet',
#   'brink',
#   'destruction'],
#  ['pevensie',
#   'siblings',
#   'return',
#   'narnia',
#   'enlisted',
#   'help',
#   'ward',
#   'evil',
#   'king',
#   'restore',
#   'rightful',
#   'heir',
#   'land',
#   'throne',
#   'prince',
#   'caspian'],
#  ['peter',
#   'parker',
#   'bitten',
#   'genetically',
#   'altered',
#   'spider',
#   'gains',
#   'newfound',
#   'spider',
#   'like',
#   'powers',
#   'ventures',
#   'solve',
#   'mystery',
#   'parent',
#   'mysterious',
#   'death'],
#  ['new',
#   'theme',
#   'park',
#   'built',
#   'original',
#   'site',
#   'jurassic',
#   'park',
#   'creates',
#   'genetically',
#   'modified',
#   'hybrid',
#   'dinosaur',
#   'escapes',
#   'containment',
#   'goes',
#   'killing',
#   'spree']]

# %%
df['Genre']=df['Genre'].apply(lambda x: x.split(','))
df['Actors']=df['Actors'].apply(lambda x: x.split(','))
df['Director']=df['Director'].apply(lambda x: x.split(','))

# %%
def clean(sentence):
    temp=[]
    for word in sentence:
        temp.append(word.lower().replace(' ',' '))
    return temp

# %%
df['Genre']=[clean(x)for x in df['Genre']]

# %%
df['Actors']=[clean(x) for x in df['Actors']]

# %%
df['Director']=[clean(x) for x in df['Director']]

# %%
df.head()
# Out:
#    Unnamed: 0                                     Title  Year  Rated  \
# 0           1                                    Avatar  2009  PG-13
# 1           2  Pirates of the Caribbean: At World's End  2007  PG-13
# 2           3                                   Spectre  2015  PG-13
# 3           4                     The Dark Knight Rises  2012  PG-13
# 4           5                           The Lone Ranger  2013  PG-13
#
#       Released  Runtime                            Genre             Director  \
# 0  18 Dec 2009  162 min   [action,  adventure,  fantasy]      [james cameron]
# 1  25 May 2007  169 min   [action,  adventure,  fantasy]     [gore verbinski]
# 2  06 Nov 2015  148 min  [action,  adventure,  thriller]         [sam mendes]
# 3  20 Jul 2012  164 min              [action,  thriller]  [christopher nolan]
# 4  03 Jul 2013  150 min   [action,  adventure,  western]     [gore verbinski]
#
#                                               Writer  \
# 0                                      James Cameron
# 1  Ted Elliott, Terry Rossio, Ted Elliott (charac...
# 2  John Logan (screenplay), Neal Purvis (screenpl...
# 3  Jonathan Nolan (screenplay), Christopher Nolan...
# 4  Justin Haythe (screenplay), Ted Elliott (scree...
#
#                                               Actors  ... tomatoUserMeter  \
# 0  [sam worthington,  zoe saldana,  sigourney wea...  ...             NaN
# 1  [johnny depp,  geoffrey rush,  orlando bloom, ...  ...             NaN
# 2  [daniel craig,  christoph waltz,  léa seydoux,...  ...             NaN
# 3  [christian bale,  gary oldman,  tom hardy,  jo...  ...             NaN
# 4  [johnny depp,  armie hammer,  william fichtner...  ...             NaN
#
#   tomatoUserRating tomatoUserReviews  \
# 0              NaN               NaN
# 1              NaN               NaN
# 2              NaN               NaN
# 3              NaN               NaN
# 4              NaN               NaN
#
#                                            tomatoURL          DVD  \
# 0            http://www.rottentomatoes.com/m/avatar/  22 Apr 2010
# 1  http://www.rottentomatoes.com/m/pirates_of_the...  04 Dec 2007
# 2      http://www.rottentomatoes.com/m/spectre_2015/  09 Feb 2016
# 3  http://www.rottentomatoes.com/m/the_dark_knigh...  03 Dec 2012
# 4   http://www.rottentomatoes.com/m/the_lone_ranger/  17 Dec 2013
#
#       BoxOffice             Production  \
# 0  $749,700,000       20th Century Fox
# 1  $309,404,152            Buena Vista
# 2  $208,777,731          Sony Pictures
# 3  $448,130,642  Warner Bros. Pictures
# 4   $89,289,910   Walt Disney Pictures
#
#                                              Website  Response  \
# 0                        http://www.avatarmovie.com/      True
# 1  http://disney.go.com/disneypictures/pirates/at...      True
# 2                                http://www.007.com/      True
# 3                 http://www.thedarkknightrises.com/      True
# 4              http://disney.go.com/the-lone-ranger/      True
#
#                                           clean_plot
# 0  [paraplegic, marine, dispatched, moon, pandora...
# 1  [captain, barbossa, turner, elizabeth, swann, ...
# 2  [cryptic, message, bond, past, sends, trail, u...
# 3  [eight, years, joker, reign, anarchy, dark, kn...
# 4  [native, american, warrior, tonto, recounts, u...
#
# [5 rows x 39 columns]

# %%
df['Actors'][0]
# Out:
# ['sam worthington', ' zoe saldana', ' sigourney weaver', ' stephen lang']

# %%
columns=['clean_plot','Genre','Actors','Director']
l=[]
for i in range(len(df)):
    words=''
    for col in columns:
        words+=' '.join(df[col][i])+' '
    l.append(words)
l
# Out:
# ['paraplegic marine dispatched moon pandora unique mission becomes torn following orders protecting world feels home action  adventure  fantasy sam worthington  zoe saldana  sigourney weaver  stephen lang james cameron ',
#  'captain barbossa turner elizabeth swann must sail edge map navigate treachery betrayal find jack sparrow make final alliances one last decisive battle action  adventure  fantasy johnny depp  geoffrey rush  orlando bloom  keira knightley gore verbinski ',
#  'cryptic message bond past sends trail uncover sinister organization battles political forces keep secret service alive bond peels back layers deceit reveal terrible truth behind spectre action  adventure  thriller daniel craig  christoph waltz  léa seydoux  ralph fiennes sam mendes ',
#  'eight years joker reign anarchy dark knight help enigmatic selina forced imposed exile save gotham city edge total annihilation brutal guerrilla terrorist bane action  thriller christian bale  gary oldman  tom hardy  joseph gordon-levitt christopher nolan ',
#  'native american warrior tonto recounts untold tales transformed john reid man law legend justice action  adventure  western johnny depp  armie hammer  william fichtner  tom wilkinson gore verbinski ',
#  'transported barsoom civil war vet discovers barren planet seemingly inhabited foot tall barbarians finding prisoner creatures escapes encounter woola princess desperate need savior action  adventure  sci-fi taylor kitsch  lynn collins  samantha morton  willem dafoe andrew stanton ',
#  'magically long haired rapunzel spent entire life tower runaway thief stumbled upon discover world first time really animation  adventure  comedy mandy moore  zachary levi  donna murphy  ron perlman nathan greno  byron howard ',
#  'strange black entity another world bonds peter parker causes inner turmoil contends new villains temptations revenge action  adventure tobey maguire  kirsten dunst  james franco  thomas haden church sam raimi ',
#  [0.01962706 0.07474857 0.03152007 0.02489945 0.0084677  0.03285003
#   0.00326254 0.00817288 0.02766728 0.00807661 0.19245623 0.01528941
#   0.03948344 0.01466193 0.04472735 0.02195787 0.00875867 0.00769703
#   0.0601272  0.01765673 1.         0.00796612 0.00779859 0.00730754]
#  [0.00864214 0.00808606 0.00709498 0.03072877 0.04115527 0.02961651
#   0.00341246 0.00854844 0.00722511 0.00844775 0.04088162 0.0038734
#   0.05847145 0.00371444 0.00426668 0.00966844 0.00916116 0.00805073
#   0.0048863  0.00777457 0.00796612 1.         0.03267101 0.00764334]
#  [0.0084604  0.00791601 0.00694577 0.00400689 0.00867055 0.02899367
#   0.00334069 0.05735242 0.00707316 0.0082701  0.0086129  0.02282375
#   0.0032542  0.04674494 0.0251411  0.00946511 0.00896849 0.11779184
#   0.00478354 0.00761107 0.00779859 0.03267101 1.         0.03476966]
#  [0.00792767 0.00741755 0.00650841 0.00375459 0.00812459 0.05477701
#   0.0290967  0.03643838 0.06316111 0.05408507 0.03574341 0.00355317
#   0.00304929 0.00340735 0.00391394 0.00886912 0.03721914 0.00738515
#   0.07271044 0.00713182 0.00730754 0.00764334 0.03476966 1.        ]]

# %%
index=pd.Series(df['Title'])
index.head()
# Out:
# 0                                      Avatar
# 1    Pirates of the Caribbean: At World's End
# 2                                     Spectre
# 3                       The Dark Knight Rises
# 4                             The Lone Ranger
# Name: Title, dtype: object

# %%
def recommend_movies(title):
    movies=[]
    idx=index[index==title].index[0]
    score=pd.Series(cosine_sim[idx]).sort_values(ascending=False)
    top10=list(score.iloc[1:11].index)

    for i in top10:
        movies.append(df['Title'][i])
    return movies

# %%
df['Title']
# Out:
# 0                                          Avatar
# 1        Pirates of the Caribbean: At World's End
# 2                                         Spectre
# 3                           The Dark Knight Rises
# 4                                 The Lone Ranger
# 5                                     John Carter
# 6                                         Tangled
# 7                                    Spider-Man 3
# 8                         Avengers: Age of Ultron
# 9                      Captain America: Civil War
# 10             Batman v Superman: Dawn of Justice
# 11              The Hobbit: An Unexpected Journey
# 12         Harry Potter and the Half-Blood Prince
# 13            The Hobbit: The Desolation of Smaug
# 14      The Hobbit: The Battle of the Five Armies
# 15    Pirates of the Caribbean: On Stranger Tides
# 16                               Superman Returns
# 17                              Quantum of Solace
# 18                                   The Avengers
# 19     Pirates of the Caribbean: Dead Man's Chest
# 20                                   Man of Steel
# 21       The Chronicles of Narnia: Prince Caspian
# 22                         The Amazing Spider-Man
# 23                                 Jurassic World
# Name: Title, dtype: object

# %%
userInput=input()
recommed=recommend_movies(userInput)
print(f"\nRecommended movies for '{userInput}':")
for movie in recommed:
    print(movie)
# Out:
# Recommended movies for 'Avatar':
# Spider-Man 3
# Superman Returns
# The Hobbit: An Unexpected Journey
# Quantum of Solace
# Spectre
# Batman v Superman: Dawn of Justice
# Pirates of the Caribbean: On Stranger Tides
# Tangled
# Pirates of the Caribbean: At World's End
# Man of Steel
